# %% [markdown]
# <a href="https://colab.research.google.com/github/MudassirABBASSi/Image-Classification-By-Deep-learning-/blob/main/Image_Classification_with_convolutation_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train,y_train),(x_test,y_test) = keras.datasets.cifar10.load_data()

# %%
x_train.shape

# %%
y_train.shape

# %%
x_test.shape

# %%
y_test.shape

# %%
def simple_plot(index):
  plt.figure(figsize=(10,1))
  plt.imshow(x_train[index])
  plt.show()

simple_plot(10)

# %%
def simple_plot(index):
  plt.figure(figsize=(10,1))
  plt.imshow(x_train[index])
  plt.xlabel(f"Image Label: {y_train[index][0]}") # Display the label
  plt.show()


simple_plot(10)

# %%
def plot_label(index):
    plt.figure(figsize=(10,1))
    plt.title(f"Label: {y_train[index][0]}")  # Access the label value and show it as title.
    # plt.axis('off') # Hide axes for cleaner view.
    plt.imshow(x_train[index]) # display the image
    plt.show() # show the plot

plot_label(1)

# %% [markdown]
# # Scaling

# %%
x_train_s = x_train/255
x_test_s = x_test/255

# %%
x_test_s.shape

# %%
x_test_s.shape

# %%
y_train_categorical = keras.utils.to_categorical(y_train , num_classes=10)
y_test_categorical = keras.utils.to_categorical(y_test , num_classes=10)

# %%
y_train[:5]

# %%
y_train_categorical[:5]

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32, 32, 3)),

    keras.layers.Dense(10, activation='softmax') # Changed to 10 units and softmax for multi-class
])
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', # Changed to categorical_crossentropy
    metrics=['accuracy'] # Corrected 'merticx' to 'metrics'
)
model.fit(x_train_s, y_train, epochs=5) # Use y_train instead of y_train_categorical

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32, 32, 3)),
    keras.layers.Dense(300, activation='relu'),
    keras.layers.Dense(10, activation='softmax') # Changed to 10 units and softmax for multi-class
])
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', # Changed to categorical_crossentropy
    metrics=['accuracy'] # Corrected 'merticx' to 'metrics'
)
model.fit(x_train_s, y_train, epochs=5) # Use y_train instead of y_train_categorical
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.2882 - loss: 1.9651
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.3923 - loss: 1.7132
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.4292 - loss: 1.6220
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4491 - loss: 1.5660
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.4623 - loss: 1.5305

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32, 32, 3)),
    keras.layers.Dense(3000, activation='relu'),
    # keras.layers.Dropout(0.2),
     keras.layers.Dense(3000, activation='relu'),
     keras.layers.Dense(3000, activation='relu'),
    #  keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax') # Changed to 10 units and softmax for multi-class
])

model.compile(
    optimizer='sgd',
    loss='categorical_crossentropy', # Changed to categorical_crossentropy
    metrics=['accuracy'] # Corrected 'merticx' to 'metrics'
)

model.fit(x_train_s, y_train_categorical, epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.3105 - loss: 1.9261
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - accuracy: 0.4196 - loss: 1.6336
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4555 - loss: 1.5370
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4820 - loss: 1.4655
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.5048 - loss: 1.4057

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32, 32, 3)),
    keras.layers.Dense(3000, activation='relu'),
    # keras.layers.Dropout(0.2),
     keras.layers.Dense(3000, activation='relu'),
     keras.layers.Dense(3000, activation='relu'),
    #  keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax') # Changed to 10 units and softmax for multi-class
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy', # Changed to categorical_crossentropy
    metrics=['accuracy'] # Corrected 'merticx' to 'metrics'
)

model.fit(x_train_s, y_train_categorical, epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.2554 - loss: 2.2286
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - accuracy: 0.3685 - loss: 1.7349
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.4073 - loss: 1.6361
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.4258 - loss: 1.5827
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.4410 - loss: 1.5427

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32, 32, 3)),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dropout(0.2),
     keras.layers.Dense(3000, activation='relu'),
     keras.layers.Dense(3000, activation='relu'),
     keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax') # Changed to 10 units and softmax for multi-class
])

model.compile(
    optimizer='sgd',
    loss='categorical_crossentropy', # Changed to categorical_crossentropy
    metrics=['accuracy'] # Corrected 'merticx' to 'metrics'
)

model.fit(x_train_s, y_train_categorical, epochs=20)
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.2809 - loss: 1.9785
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - accuracy: 0.4013 - loss: 1.6865
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4360 - loss: 1.5948
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4523 - loss: 1.5399
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4731 - loss: 1.4884
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4850 - loss: 1.4472
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4981 - loss: 1.4081
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5133 - loss: 1.3812
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5205 - loss: 1.3505
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.5334 - loss: 1.3170
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.5399 - loss: 1.2960
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5483 - loss: 1.2646
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.5621 - loss: 1.2455
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5698 - loss: 1.2220
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.5740 - loss: 1.2045
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.5822 - loss: 1.1777
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.5937 - loss: 1.1437
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6018 - loss: 1.1240
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.6058 - loss: 1.0999
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.6146 - loss: 1.0872

# %% [markdown]
# #Convolutation Neural network

# %%
from tensorflow.keras import layers

model1 = keras.Sequential([
                        #  Convolutation layer
    layers.Conv2D(filters=32,activation='relu',kernel_size =(3,3),input_shape =(32,32,3))  ,
    layers.MaxPooling2D(2,2),
                          # Dense Layer
    keras.layers.Flatten(input_shape=(32, 32, 3)),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax') # Changed to 10 units and softmax for multi-class
])
model1.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', # Changed to categorical_crossentropy
    metrics=['accuracy'] # Corrected 'merticx' to 'metrics'
)
model1.fit(x_train_s, y_train, epochs=5)

# %% [markdown]
# # Multiple Convolutional layers Nural Network

# %%
model2 = keras.Sequential([
                        #  Convolutation layer
    layers.Conv2D(filters=32,activation='relu',kernel_size =(3,3),input_shape =(32,32,3))  ,
    layers.MaxPooling2D(2,2),
    layers.Conv2D(filters=62,activation='relu',kernel_size =(3,3),input_shape =(32,32,3))  ,
    layers.MaxPooling2D(2,2),

                          # Dense Layer
    keras.layers.Flatten(input_shape=(32, 32, 3)),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax') # Changed to 10 units and softmax for multi-class
])
model2.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', # Changed to categorical_crossentropy
    metrics=['accuracy'] # Corrected 'merticx' to 'metrics'
)
model2.fit(x_train_s, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.2077 - loss: 2.1472
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.4219 - loss: 1.6002
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.4937 - loss: 1.4015
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.5459 - loss: 1.2722
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.5925 - loss: 1.1481

# %%
model3 = keras.Sequential([
                        #  Convolutation layer
    layers.Conv2D(filters=32,activation='relu',kernel_size =(3,3),input_shape =(32,32,3))  ,
    layers.MaxPooling2D(2,2),
    layers.Conv2D(filters=62,activation='relu',kernel_size =(3,3),input_shape =(32,32,3))  ,
    layers.MaxPooling2D(2,2),
     layers.Conv2D(filters=102,activation='relu',kernel_size =(3,3),input_shape =(32,32,3))  ,
    layers.MaxPooling2D(2,2),

                          # Dense Layer
    keras.layers.Flatten(input_shape=(32, 32, 3)),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax') # Changed to 10 units and softmax for multi-class
])
model3.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', # Changed to categorical_crossentropy
    metrics=['accuracy'] # Corrected 'merticx' to 'metrics'
)
model3.fit(x_train_s, y_train, epochs=5)

# %%
cnn = keras.Sequential([
                        #  Convolutation layer
    layers.Conv2D(filters=32,activation='relu',kernel_size =(3,3),input_shape =(32,32,3))  ,
    layers.MaxPooling2D(2,2),

    layers.Conv2D(filters=62,activation='relu',kernel_size =(3,3),input_shape =(32,32,3))  ,
    layers.MaxPooling2D(2,2),

     layers.Conv2D(filters=102,activation='relu',kernel_size =(3,3),input_shape =(32,32,3))  ,
    layers.MaxPooling2D(2,2),

                          # Dense Layer
    keras.layers.Flatten(input_shape=(32, 32, 3)),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax') # Changed to 10 units and softmax for multi-class
])
cnn.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy', # Changed to categorical_crossentropy
    metrics=['accuracy'] # Corrected 'merticx' to 'metrics'
)
cnn.fit(x_train_s, y_train, epochs=50)

# %%
# prompt: evalution

# Evaluate the model on the test data
loss, accuracy = cnn.evaluate(x_test_s, y_test) # Use x_test_s instead of x_test
print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")

# %%
y_pred = cnn.predict(x_test_s)
y_class  = [np.argmax(element) for element in y_pred]

# Compare predictions with actual values for the first 5 images
for i in range(10):
    print(f"Image {i+1}:")
    print(f"  Predicted class: {y_class[i]}")
    print(f"  Actual class: {y_test[i][0]}")

    # Optional: Display the image and its label
    plt.figure(figsize=(2,2))
    plt.imshow(x_test[i])
    plt.title(f"Predicted: {y_class[i]}, Actual: {y_test[i][0]}")
    # plt.show()

# %%
# prompt: from sklearn.metrics import confusion_matrix,classification_report
# cm = confusion_matrix(y_test,y_class)

from sklearn.metrics import confusion_matrix, classification_report

cm = confusion_matrix(y_test, y_class)
# print(cm)

# Assuming you have y_test and y_class defined
print(classification_report(y_test, y_class))
